# %%
#optimized retrieval 
import urllib.request
import csv
import pandas as pd 

def time(code):
    if code >= 6 and code <= 11:
        return 'Morning'
    elif code >= 12 and code <= 16:
        return 'Afternoon'
    elif code >= 17 and code <= 19:
        return 'Evening'
    elif code >= 20 or code <= 5:
        return 'Night'

def offense_type(code):
    if code in larceny:
        return 'Larceny'
    elif code in manslaughter:
        return 'Manslaughter'
    elif code in driving_under_influence:
        return 'Driving Under Influence'
    elif code in rape_sexual_assault:
        return 'Rape/Sexual Assault'
    elif code in robbery:
        return 'Robbery'
    elif code in assault_battery:
        return 'Assault/Battery'
    elif code in kidnapping:
        return 'Kidnapping'
    elif code in burglary:
        return 'Burglary'
    elif code in bombs_explosives:
        return 'Bombs/Explosives'
    elif code in harassment:
        return 'Harassment'
    elif code in posession_drugs:
        return 'Possession'
    elif code in weapons:
        return 'Weapons'
    elif code in arson:
        return 'Arson'
    elif code in breaking_entering:
        return 'Breaking and Entering'
    elif code in child_abuse_endangerment:
        return 'Child Abuse/Endangerment'
    elif code in disorderly_conduct:
        return 'Disorderly Conduct'
    elif code in public_drinking:
        return 'Public Drinking'
    else:
        return None

larceny = [612, 617, 619, 621, 611, 631, 612, 622, 632]
manslaughter = [123, 121, 111, 121, 122, 123, 124, 125]
driving_under_influence = [2102, 2101]
rape_sexual_assault = [254, 271, 244, 251, 241, 243, 261, 252, 253, 1704, 222, 230, 236, 211, 232, 233, 224, 213, 223, 231, 237, 212, 234, 235, 1720, 1703]
robbery = [301, 311, 351, 361, 371, 381, 301, 302, 304, 303, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 434, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 373, 374, 375, 376, 377, 378, 379, 380]
assault_battery = [801, 802, 423, 413, 1702, 401, 402, 403, 404, 411, 413, 421, 422, 423, 424, 431, 432, 433, 1727, 1726, 1725, 1702]
kidnapping = [2511, 2622, 2611]
burglary = [541, 540, 562, 561, 542, 521, 522, 560]
bombs_explosives = [2648, 2618, 3123, 3107]
harassment = [2670, 2629]
posession_drugs = [1810, 1847, 1840, 1843, 1841, 1848, 1850]
weapons = [3016, 3017, 1501, 1503, 1502, 1504, 1510, 3119]
arson = [900, 901, 902, 905, 906, 907, 920, 930]
breaking_entering = [520, 521, 522, 527, 510, 511, 512, 517, 540, 541, 542, 543, 547, 530, 531, 532, 537]
child_abuse_endangerment = [2003, 2005]
disorderly_conduct = [2405, 2403]
public_drinking = [2646]

master_list = larceny + manslaughter + driving_under_influence + rape_sexual_assault + robbery + assault_battery + kidnapping + burglary +\
bombs_explosives + harassment + posession_drugs + weapons + arson + breaking_entering + child_abuse_endangerment + disorderly_conduct + \
public_drinking


if __name__ == "__main__":
    #reading in csv to create dataframe
    df = pd.read_csv('crime_incident_report_august_2015_to_date.csv')

    # removing irrelevant columns and null values
    cols = [0,2,3,5,6,7,9,10,11,12,13,14,15]
    df.drop(df.columns[cols],axis=1,inplace=True)

    # removing null or invalid values
    crime_data = df[df.DISTRICT.notnull()]
    crime_data = crime_data[crime_data.Location != '(0E-8, 0E-8)']
    crime_data.columns = ['offense_code', 'district', 'hour', 'location']
    
    # filters through relevant data and creates new dataframe
    crime_data = crime_data[crime_data['offense_code'].isin(master_list)]
    
    # assigns appropriate offense types for each offense code
    crime_data['offense_type']  =''    
    crime_data['tod'] = ''
    for ind, row in crime_data.iterrows():
        crime_data.loc[ind, 'offense_type'] = offense_type(row['offense_code'])
        crime_data.loc[ind, 'tod'] = time(int(row['hour']))
        
    # drop offense code column
    #crime_data = crime_data.drop('offense_code', 1)
    crime_data.drop('hour', axis=1, inplace=True)
    # save df to csv
    crime_data.to_csv('cleaned_crime_data.csv', index=False)
    print(crime_data)
# Out:
#         offense_code district                     location  \
# 5                520       B3  (42.29474312, -71.08503786)
# 15               522       A1  (42.36339791, -71.05600208)
# 22              1810      C11  (42.29794304, -71.05175837)
# 33               560       D4  (42.34860972, -71.07538812)
# 38               413       C6  (42.32971183, -71.05268388)
# 44               802      E13  (42.32387703, -71.10409269)
# 48               617      C11  (42.30870401, -71.06844484)
# 55               619       C6  (42.33339546, -71.05179708)
# 59               802       D4   (42.3425037, -71.10178609)
# 69               542      C11  (42.31040916, -71.06239921)
# 73               522       E5  (42.26523483, -71.15843028)
# 74               802       B2  (42.32337421, -71.09103005)
# 82               802       C6  (42.32775523, -71.05256837)
# 86               802       B3   (42.29597658, -71.0793399)
# 89               381       B3   (42.27653731, -71.0933951)
# 95               520      E18   (42.26809427, -71.0990997)
# 107              802       A1  (42.35120708, -71.05987799)
# 109              413      C11  (42.31007897, -71.07228855)
# 127              802      E13   (42.31865822, -71.1006718)
# 129              522      E13  (42.31176766, -71.09971564)
# 132             2629      E13  (42.32624204, -71.10317575)
# 133              520      D14   (42.3557137, -71.15532953)
# 134              802       B2  (42.33380238, -71.08880867)
# 135              617       A1  (42.36108179, -71.05698344)
# 136             1848       A1  (42.35715749, -71.06506539)
# 139             3119       B2  (42.32866284, -71.08563401)
# 142             2670      E18  (42.26804634, -71.10440439)
# 143             2403       B3  (42.29389648, -71.08451577)
# 163              522       A7  (42.37887838, -71.03643423)
# 164              423      E13  (42.32470968, -71.10880411)
# ...              ...      ...                          ...
# 137817           801       D4   (42.3414661, -71.09082781)
# 137825           413       B2  (42.31369016, -71.07696741)
# 137829          1843       B3  (42.28482577, -71.09137369)
# 137832          1841      A15  (42.37663167, -71.05593196)
# 137833           619       C6  (42.33152148, -71.07085307)
# 137842           617      E13  (42.32214915, -71.10091019)
# 137843           802      E18   (42.2613358, -71.11233325)
# 137847           802       B3  (42.29997367, -71.08206122)
# 137853          2629       B3  (42.27855984, -71.09199697)
# 137862           802       D4   (42.33486614, -71.0785518)
# 137864          1810      E18  (42.25621592, -71.12401947)
# 137870           802       A1  (42.35591935, -71.06000539)
# 137871          1810      E18  (42.25621592, -71.12401947)
# 137878           617       A1    (42.3483823, -71.0638195)
# 137885           802       A7  (42.37864819, -71.03089238)
# 137891          2629       B3   (42.2777688, -71.09334841)
# 137893           617      C11  (42.28492596, -71.07135254)
# 137894           802      E18  (42.25188297, -71.11915243)
# 137898           423       B3  (42.29268711, -71.08038427)
# 137899           619      C11  (42.30570822, -71.06015451)
# 137900           617       D4    (42.3483427, -71.0722253)
# 137908           802      E13  (42.31860691, -71.10621876)
# 137917          1843       B3  (42.28482577, -71.09137369)
# 137921          2403      E13  (42.32290252, -71.10220402)
# 137926           301      E13  (42.31615184, -71.09795135)
# 137930          2629      E13  (42.31538816, -71.10239088)
# 137934           619       D4   (42.3503787, -71.07626098)
# 137936          1843       B3  (42.28482577, -71.09137369)
# 137937           617       C6  (42.31957856, -71.04032766)
# 137939          3119       B2  (42.33367922, -71.09187755)
#
#                  offense_type        tod
# 5       Breaking and Entering    Evening
# 15                   Burglary    Evening
# 22                 Possession    Morning
# 33                   Burglary  Afternoon
# 38            Assault/Battery    Morning
# 44            Assault/Battery      Night
# 48                    Larceny    Morning
# 55                    Larceny    Morning
# 59            Assault/Battery  Afternoon
# 69                   Burglary    Evening
# 73                   Burglary    Evening
# 74            Assault/Battery  Afternoon
# 82            Assault/Battery      Night
# 86            Assault/Battery    Morning
# 89                    Robbery      Night
# 95      Breaking and Entering    Morning
# 107           Assault/Battery      Night
# 109           Assault/Battery  Afternoon
# 127           Assault/Battery      Night
# 129                  Burglary      Night
# 132                Harassment  Afternoon
# 133     Breaking and Entering    Morning
# 134           Assault/Battery  Afternoon
# 135                   Larceny      Night
# 136                Possession  Afternoon
# 139                   Weapons      Night
# 142                Harassment  Afternoon
# 143        Disorderly Conduct      Night
# 163                  Burglary    Morning
# 164           Assault/Battery      Night
# ...                       ...        ...
# 137817        Assault/Battery      Night
# 137825        Assault/Battery    Morning
# 137829             Possession    Evening
# 137832             Possession  Afternoon
# 137833                Larceny    Evening
# 137842                Larceny    Evening
# 137843        Assault/Battery      Night
# 137847        Assault/Battery  Afternoon
# 137853             Harassment  Afternoon
# 137862        Assault/Battery    Morning
# 137864             Possession  Afternoon
# 137870        Assault/Battery  Afternoon
# 137871             Possession    Morning
# 137878                Larceny  Afternoon
# 137885        Assault/Battery      Night
# 137891             Harassment    Evening
# 137893                Larceny    Evening
# 137894        Assault/Battery      Night
# 137898        Assault/Battery  Afternoon
# 137899                Larceny    Morning
# 137900                Larceny      Night
# 137908        Assault/Battery  Afternoon
# 137917             Possession    Evening
# 137921     Disorderly Conduct      Night
# 137926                Robbery      Night
# 137930             Harassment      Night
# 137934                Larceny    Evening
# 137936             Possession      Night
# 137937                Larceny      Night
# 137939                Weapons  Afternoon
#
# [29859 rows x 5 columns]
