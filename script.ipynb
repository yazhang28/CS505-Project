# %%
#optimized retrieval 
import urllib.request
import csv
import pandas as pd 

def time(code):
    if code >= 6 and code <= 11:
        return 'Morning'
    elif code >= 12 and code <= 16:
        return 'Afternoon'
    elif code >= 17 and code <= 19:
        return 'Evening'
    elif code >= 20 or code <= 5:
        return 'Night'

def offense_type(code):
    if code in larceny:
        return 'Larceny'
    elif code in manslaughter:
        return 'Manslaughter'
    elif code in driving_under_influence:
        return 'Driving Under Influence'
    elif code in rape_sexual_assault:
        return 'Rape/Sexual Assault'
    elif code in robbery:
        return 'Robbery'
    elif code in assault_battery:
        return 'Assault/Battery'
    elif code in kidnapping:
        return 'Kidnapping'
    elif code in burglary:
        return 'Burglary'
    elif code in bombs_explosives:
        return 'Bombs/Explosives'
    elif code in harassment:
        return 'Harassment'
    elif code in posession_drugs:
        return 'Possession'
    elif code in weapons:
        return 'Weapons'
    elif code in arson:
        return 'Arson'
    elif code in breaking_entering:
        return 'Breaking and Entering'
    elif code in child_abuse_endangerment:
        return 'Child Abuse/Endangerment'
    elif code in disorderly_conduct:
        return 'Disorderly Conduct'
    elif code in public_drinking:
        return 'Public Drinking'
    else:
        return None

larceny = [612, 617, 619, 621, 611, 631, 612, 622, 632]
manslaughter = [123, 121, 111, 121, 122, 123, 124, 125]
driving_under_influence = [2102, 2101]
rape_sexual_assault = [254, 271, 244, 251, 241, 243, 261, 252, 253, 1704, 222, 230, 236, 211, 232, 233, 224, 213, 223, 231, 237, 212, 234, 235, 1720, 1703]
robbery = [301, 311, 351, 361, 371, 381, 301, 302, 304, 303, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 434, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 373, 374, 375, 376, 377, 378, 379, 380]
assault_battery = [801, 802, 423, 413, 1702, 401, 402, 403, 404, 411, 413, 421, 422, 423, 424, 431, 432, 433, 1727, 1726, 1725, 1702]
kidnapping = [2511, 2622, 2611]
burglary = [541, 540, 562, 561, 542, 521, 522, 560]
bombs_explosives = [2648, 2618, 3123, 3107]
harassment = [2670, 2629]
posession_drugs = [1810, 1847, 1840, 1843, 1841, 1848, 1850]
weapons = [3016, 3017, 1501, 1503, 1502, 1504, 1510, 3119]
arson = [900, 901, 902, 905, 906, 907, 920, 930]
breaking_entering = [520, 521, 522, 527, 510, 511, 512, 517, 540, 541, 542, 543, 547, 530, 531, 532, 537]
child_abuse_endangerment = [2003, 2005]
disorderly_conduct = [2405, 2403]
public_drinking = [2646]

master_list = larceny + manslaughter + driving_under_influence + rape_sexual_assault + robbery + assault_battery + kidnapping + burglary +\
bombs_explosives + harassment + posession_drugs + weapons + arson + breaking_entering + child_abuse_endangerment + disorderly_conduct + \
public_drinking


if __name__ == "__main__":
    #reading in csv to create dataframe
    df = pd.read_csv('crime_incident_report_august_2015_to_date.csv')

    # removing irrelevant columns and null values
    cols = [0,2,3,5,6,7,9,10,12,13,14,15]
    df.drop(df.columns[cols],axis=1,inplace=True)

    # removing null or invalid values
    crime_data = df[df.DISTRICT.notnull()]
    crime_data = crime_data[crime_data.Location != '(0E-8, 0E-8)']
    crime_data.columns = ['offense_code', 'district', 'hour', 'day_of_week', 'location']
    
    # filters through relevant data and creates new dataframe
    crime_data = crime_data[crime_data['offense_code'].isin(master_list)]
    
    # assigns appropriate offense types for each offense code
    crime_data['offense_type']  =''    
    crime_data['tod'] = ''
    for ind, row in crime_data.iterrows():
        crime_data.loc[ind, 'offense_type'] = offense_type(row['offense_code'])
        crime_data.loc[ind, 'tod'] = time(int(row['hour']))
        
    # drop offense code column
    #crime_data = crime_data.drop('offense_code', 1)
#     crime_data.drop('hour', axis=1, inplace=True)

    # save df to csv
    crime_data.to_csv('cleaned_crime_data.csv', index=False)
    print(crime_data)
# Out:
#         offense_code district  hour day_of_week                     location  \
# 5                520       B3    17   Wednesday  (42.29474312, -71.08503786)
# 15               522       A1    19    Saturday  (42.36339791, -71.05600208)
# 22              1810      C11    11      Monday  (42.29794304, -71.05175837)
# 33               560       D4    13     Tuesday  (42.34860972, -71.07538812)
# 38               413       C6     8      Friday  (42.32971183, -71.05268388)
# 44               802      E13    21   Wednesday  (42.32387703, -71.10409269)
# 48               617      C11     6    Saturday  (42.30870401, -71.06844484)
# 55               619       C6    10      Monday  (42.33339546, -71.05179708)
# 59               802       D4    16    Saturday   (42.3425037, -71.10178609)
# 69               542      C11    18    Saturday  (42.31040916, -71.06239921)
# 73               522       E5    19    Thursday  (42.26523483, -71.15843028)
# 74               802       B2    15      Sunday  (42.32337421, -71.09103005)
# 83               802       C6    22      Sunday  (42.32775523, -71.05256837)
# 87               802       B3    10      Monday   (42.29597658, -71.0793399)
# 90               381       B3     3      Monday   (42.27653731, -71.0933951)
# 96               520      E18    11    Thursday   (42.26809427, -71.0990997)
# 108              802       A1     1      Sunday  (42.35120708, -71.05987799)
# 110              413      C11    13      Friday  (42.31007897, -71.07228855)
# 128              802      E13    20    Saturday   (42.31865822, -71.1006718)
# 131              522      E13    22      Friday  (42.31176766, -71.09971564)
# 134             2629      E13    12      Friday  (42.32624204, -71.10317575)
# 135              520      D14     9      Sunday   (42.3557137, -71.15532953)
# 136              802       B2    14      Monday  (42.33380238, -71.08880867)
# 137              617       A1     0      Friday  (42.36108179, -71.05698344)
# 138             1848       A1    15      Friday  (42.35715749, -71.06506539)
# 141             3119       B2    22      Friday  (42.32866284, -71.08563401)
# 144             2670      E18    16   Wednesday  (42.26804634, -71.10440439)
# 145             2403       B3     1    Saturday  (42.29389648, -71.08451577)
# 165              522       A7     8   Wednesday  (42.37887838, -71.03643423)
# 166              423      E13    23   Wednesday  (42.32470968, -71.10880411)
# ...              ...      ...   ...         ...                          ...
# 137567           619      D14    14     Tuesday   (42.3468275, -71.14319087)
# 137573           521      E18    14      Friday   (42.26809427, -71.0990997)
# 137574          1810      E18    19      Friday  (42.25621592, -71.12401947)
# 137577           413      C11     6    Thursday  (42.31363409, -71.06778025)
# 137580           413       A1     4     Tuesday  (42.36322697, -71.05390879)
# 137595           619       C6     0     Tuesday  (42.31957856, -71.04032766)
# 137600           423       B3    22     Tuesday  (42.27995083, -71.08185417)
# 137607           617      D14     9   Wednesday  (42.35910694, -71.14124272)
# 137609           619       B3     8    Thursday  (42.30084929, -71.08522128)
# 137617           413       B2    15     Tuesday   (42.3203979, -71.06181748)
# 137619           617       E5    14      Monday  (42.26932098, -71.17204938)
# 137620           301       D4     8      Monday   (42.34800978, -71.0766976)
# 137623           619      E18    11     Tuesday   (42.26128526, -71.1215525)
# 137624           522       B2    19    Saturday  (42.31820434, -71.06657287)
# 137632          2629       B2    11    Thursday   (42.3304334, -71.10268549)
# 137636           413       C6     0    Thursday  (42.32779976, -71.06771009)
# 137639           617       C6    11      Friday  (42.33788808, -71.03800907)
# 137640           801       B2    22   Wednesday  (42.32104169, -71.07215291)
# 137641           619       B3    12     Tuesday  (42.29346977, -71.07512548)
# 137643          2629       B2    14      Monday  (42.32104457, -71.09281974)
# 137645           562      C11    11      Friday   (42.30010597, -71.0710271)
# 137649           802       B2    14      Monday  (42.31768581, -71.06656219)
# 137651           619       A1    17    Saturday  (42.36489527, -71.06050249)
# 137654           301       B2    13      Monday  (42.31096953, -71.08461836)
# 137658           802       B2    23      Friday  (42.32851529, -71.07653709)
# 137660           522       B3    13      Monday  (42.29755695, -71.08182045)
# 137661           801      A15    16      Monday  (42.37474921, -71.05270605)
# 137663           617      E18    18      Sunday  (42.26886966, -71.11802566)
# 137664           802      A15     8     Tuesday   (42.3787592, -71.05598086)
# 137677           802       B2     8      Monday  (42.31772429, -71.09243239)
#
#                  offense_type        tod
# 5       Breaking and Entering    Evening
# 15                   Burglary    Evening
# 22                 Possession    Morning
# 33                   Burglary  Afternoon
# 38            Assault/Battery    Morning
# 44            Assault/Battery      Night
# 48                    Larceny    Morning
# 55                    Larceny    Morning
# 59            Assault/Battery  Afternoon
# 69                   Burglary    Evening
# 73                   Burglary    Evening
# 74            Assault/Battery  Afternoon
# 83            Assault/Battery      Night
# 87            Assault/Battery    Morning
# 90                    Robbery      Night
# 96      Breaking and Entering    Morning
# 108           Assault/Battery      Night
# 110           Assault/Battery  Afternoon
# 128           Assault/Battery      Night
# 131                  Burglary      Night
# 134                Harassment  Afternoon
# 135     Breaking and Entering    Morning
# 136           Assault/Battery  Afternoon
# 137                   Larceny      Night
# 138                Possession  Afternoon
# 141                   Weapons      Night
# 144                Harassment  Afternoon
# 145        Disorderly Conduct      Night
# 165                  Burglary    Morning
# 166           Assault/Battery      Night
# ...                       ...        ...
# 137567                Larceny  Afternoon
# 137573               Burglary  Afternoon
# 137574             Possession    Evening
# 137577        Assault/Battery    Morning
# 137580        Assault/Battery      Night
# 137595                Larceny      Night
# 137600        Assault/Battery      Night
# 137607                Larceny    Morning
# 137609                Larceny    Morning
# 137617        Assault/Battery  Afternoon
# 137619                Larceny  Afternoon
# 137620                Robbery    Morning
# 137623                Larceny    Morning
# 137624               Burglary    Evening
# 137632             Harassment    Morning
# 137636        Assault/Battery      Night
# 137639                Larceny    Morning
# 137640        Assault/Battery      Night
# 137641                Larceny  Afternoon
# 137643             Harassment  Afternoon
# 137645               Burglary    Morning
# 137649        Assault/Battery  Afternoon
# 137651                Larceny    Evening
# 137654                Robbery  Afternoon
# 137658        Assault/Battery      Night
# 137660               Burglary  Afternoon
# 137661        Assault/Battery  Afternoon
# 137663                Larceny    Evening
# 137664        Assault/Battery    Morning
# 137677        Assault/Battery    Morning
#
# [29809 rows x 7 columns]
