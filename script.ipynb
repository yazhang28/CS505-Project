# %%
#optimized retrieval 
import urllib.request
import csv
import pandas as pd 

def time(code):
    if code >= 6 and code <= 11:
        return 'Morning'
    elif code >= 12 and code <= 16:
        return 'Afternoon'
    elif code >= 17 and code <= 19:
        return 'Evening'
    elif code >= 20 or code <= 5:
        return 'Night'

def offense_type(code):
    if code in larceny:
        return 'Larceny'
    elif code in manslaughter:
        return 'Manslaughter'
    elif code in driving_under_influence:
        return 'Driving Under Influence'
    elif code in rape_sexual_assault:
        return 'Rape/Sexual Assault'
    elif code in robbery:
        return 'Robbery'
    elif code in assault_battery:
        return 'Assault/Battery'
    elif code in kidnapping:
        return 'Kidnapping'
    elif code in burglary:
        return 'Burglary'
    elif code in bombs_explosives:
        return 'Bombs/Explosives'
    elif code in harassment:
        return 'Harassment'
    elif code in posession_drugs:
        return 'Possession'
    elif code in weapons:
        return 'Weapons'
    elif code in arson:
        return 'Arson'
    elif code in breaking_entering:
        return 'Breaking and Entering'
    elif code in child_abuse_endangerment:
        return 'Child Abuse/Endangerment'
    elif code in disorderly_conduct:
        return 'Disorderly Conduct'
    elif code in public_drinking:
        return 'Public Drinking'
    else:
        return None

larceny = [612, 617, 619, 621, 611, 631, 612, 622, 632]
manslaughter = [123, 121, 111, 121, 122, 123, 124, 125]
driving_under_influence = [2102, 2101]
rape_sexual_assault = [254, 271, 244, 251, 241, 243, 261, 252, 253, 1704, 222, 230, 236, 211, 232, 233, 224, 213, 223, 231, 237, 212, 234, 235, 1720, 1703]
robbery = [301, 311, 351, 361, 371, 381, 301, 302, 304, 303, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 434, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 373, 374, 375, 376, 377, 378, 379, 380]
assault_battery = [801, 802, 423, 413, 1702, 401, 402, 403, 404, 411, 413, 421, 422, 423, 424, 431, 432, 433, 1727, 1726, 1725, 1702]
kidnapping = [2511, 2622, 2611]
burglary = [541, 540, 562, 561, 542, 521, 522, 560]
bombs_explosives = [2648, 2618, 3123, 3107]
harassment = [2670, 2629]
posession_drugs = [1810, 1847, 1840, 1843, 1841, 1848, 1850]
weapons = [3016, 3017, 1501, 1503, 1502, 1504, 1510, 3119]
arson = [900, 901, 902, 905, 906, 907, 920, 930]
breaking_entering = [520, 521, 522, 527, 510, 511, 512, 517, 540, 541, 542, 543, 547, 530, 531, 532, 537]
child_abuse_endangerment = [2003, 2005]
disorderly_conduct = [2405, 2403]
public_drinking = [2646]

master_list = larceny + manslaughter + driving_under_influence + rape_sexual_assault + robbery + assault_battery + kidnapping + burglary +\
bombs_explosives + harassment + posession_drugs + weapons + arson + breaking_entering + child_abuse_endangerment + disorderly_conduct + \
public_drinking


if __name__ == "__main__":
    #reading in csv to create dataframe
    df = pd.read_csv('crime_incident_report_august_2015_to_date.csv')

    # removing irrelevant columns and null values
    cols = [0,2,3,5,6,7,9,10,11,12,13,14,15]
    df.drop(df.columns[cols],axis=1,inplace=True)

    # removing null or invalid values
    crime_data = df[df.DISTRICT.notnull()]
    crime_data = crime_data[crime_data.Location != '(0E-8, 0E-8)']
    crime_data.columns = ['offense_code', 'district', 'hour', 'location']
    
    # filters through relevant data and creates new dataframe
    crime_data = crime_data[crime_data['offense_code'].isin(master_list)]
    
    # assigns appropriate offense types for each offense code
    crime_data['offense_type']  =''    
    crime_data['tod'] = ''
    for ind, row in crime_data.iterrows():
        crime_data.loc[ind, 'offense_type'] = offense_type(row['offense_code'])
        crime_data.loc[ind, 'tod'] = time(int(row['hour']))
        
    # drop offense code column
    crime_data = crime_data.drop('offense_code', 1)
    crime_data.drop('hour', axis=1, inplace=True)
    # save df to csv
    crime_data.to_csv('cleaned_crime_data.csv', index=False)
    print(crime_data)
# Out:
#        district                     location           offense_type        tod
# 5            B3  (42.29474312, -71.08503786)  Breaking and Entering    Evening
# 15           A1  (42.36339791, -71.05600208)               Burglary    Evening
# 22          C11  (42.29794304, -71.05175837)             Possession    Morning
# 33           D4  (42.34860972, -71.07538812)               Burglary  Afternoon
# 38           C6  (42.32971183, -71.05268388)        Assault/Battery    Morning
# 44          E13  (42.32387703, -71.10409269)        Assault/Battery      Night
# 48          C11  (42.30870401, -71.06844484)                Larceny    Morning
# 55           C6  (42.33339546, -71.05179708)                Larceny    Morning
# 59           D4   (42.3425037, -71.10178609)        Assault/Battery  Afternoon
# 69          C11  (42.31040916, -71.06239921)               Burglary    Evening
# 73           E5  (42.26523483, -71.15843028)               Burglary    Evening
# 74           B2  (42.32337421, -71.09103005)        Assault/Battery  Afternoon
# 82           C6  (42.32775523, -71.05256837)        Assault/Battery      Night
# 86           B3   (42.29597658, -71.0793399)        Assault/Battery    Morning
# 89           B3   (42.27653731, -71.0933951)                Robbery      Night
# 95          E18   (42.26809427, -71.0990997)  Breaking and Entering    Morning
# 107          A1  (42.35120708, -71.05987799)        Assault/Battery      Night
# 109         C11  (42.31007897, -71.07228855)        Assault/Battery  Afternoon
# 127         E13   (42.31865822, -71.1006718)        Assault/Battery      Night
# 129         E13  (42.31176766, -71.09971564)               Burglary      Night
# 132         E13  (42.32624204, -71.10317575)             Harassment  Afternoon
# 133         D14   (42.3557137, -71.15532953)  Breaking and Entering    Morning
# 134          B2  (42.33380238, -71.08880867)        Assault/Battery  Afternoon
# 135          A1  (42.36108179, -71.05698344)                Larceny      Night
# 136          A1  (42.35715749, -71.06506539)             Possession  Afternoon
# 139          B2  (42.32866284, -71.08563401)                Weapons      Night
# 142         E18  (42.26804634, -71.10440439)             Harassment  Afternoon
# 143          B3  (42.29389648, -71.08451577)     Disorderly Conduct      Night
# 163          A7  (42.37887838, -71.03643423)               Burglary    Morning
# 164         E13  (42.32470968, -71.10880411)        Assault/Battery      Night
# ...         ...                          ...                    ...        ...
# 137817       D4   (42.3414661, -71.09082781)        Assault/Battery      Night
# 137825       B2  (42.31369016, -71.07696741)        Assault/Battery    Morning
# 137829       B3  (42.28482577, -71.09137369)             Possession    Evening
# 137832      A15  (42.37663167, -71.05593196)             Possession  Afternoon
# 137833       C6  (42.33152148, -71.07085307)                Larceny    Evening
# 137842      E13  (42.32214915, -71.10091019)                Larceny    Evening
# 137843      E18   (42.2613358, -71.11233325)        Assault/Battery      Night
# 137847       B3  (42.29997367, -71.08206122)        Assault/Battery  Afternoon
# 137853       B3  (42.27855984, -71.09199697)             Harassment  Afternoon
# 137862       D4   (42.33486614, -71.0785518)        Assault/Battery    Morning
# 137864      E18  (42.25621592, -71.12401947)             Possession  Afternoon
# 137870       A1  (42.35591935, -71.06000539)        Assault/Battery  Afternoon
# 137871      E18  (42.25621592, -71.12401947)             Possession    Morning
# 137878       A1    (42.3483823, -71.0638195)                Larceny  Afternoon
# 137885       A7  (42.37864819, -71.03089238)        Assault/Battery      Night
# 137891       B3   (42.2777688, -71.09334841)             Harassment    Evening
# 137893      C11  (42.28492596, -71.07135254)                Larceny    Evening
# 137894      E18  (42.25188297, -71.11915243)        Assault/Battery      Night
# 137898       B3  (42.29268711, -71.08038427)        Assault/Battery  Afternoon
# 137899      C11  (42.30570822, -71.06015451)                Larceny    Morning
# 137900       D4    (42.3483427, -71.0722253)                Larceny      Night
# 137908      E13  (42.31860691, -71.10621876)        Assault/Battery  Afternoon
# 137917       B3  (42.28482577, -71.09137369)             Possession    Evening
# 137921      E13  (42.32290252, -71.10220402)     Disorderly Conduct      Night
# 137926      E13  (42.31615184, -71.09795135)                Robbery      Night
# 137930      E13  (42.31538816, -71.10239088)             Harassment      Night
# 137934       D4   (42.3503787, -71.07626098)                Larceny    Evening
# 137936       B3  (42.28482577, -71.09137369)             Possession      Night
# 137937       C6  (42.31957856, -71.04032766)                Larceny      Night
# 137939       B2  (42.33367922, -71.09187755)                Weapons  Afternoon
#
# [29859 rows x 4 columns]
